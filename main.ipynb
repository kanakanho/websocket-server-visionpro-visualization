# %%
# %load_ext autoreload
# %autoreload 2

import json
import os
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import cv2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# 自作モジュール
import module.make_csv as make_csv
import module.make_png as make_png
import module.make_movie as make_movie

# %%
# json データの csv 化
make_csv.make_csv()

# %%
# 画像を作成
make_png.make_png()

# %%
# 動画にする
make_movie.make_movie()

# %%
# データを読み込む
files = os.listdir("data")
files = [f for f in files if f.endswith(".json")]
files = sorted(files)
latest_file = files[-1].removesuffix(".json")
df = pd.read_csv(f"data/{latest_file}.csv")

# %% [markdown]
# DataFrame のヘッダー
# ```
# time,wrist_0_0,wrist_0_1,wrist_0_2,wrist_0_3,wrist_1_0,wrist_1_1,wrist_1_2,wrist_1_3,wrist_2_0,wrist_2_1,wrist_2_2,wrist_2_3,wrist_3_0,wrist_3_1,wrist_3_2,wrist_3_3,thumbKnuckle_0_0,thumbKnuckle_0_1,thumbKnuckle_0_2,thumbKnuckle_0_3,thumbKnuckle_1_0,thumbKnuckle_1_1,thumbKnuckle_1_2,thumbKnuckle_1_3,thumbKnuckle_2_0,thumbKnuckle_2_1,thumbKnuckle_2_2,thumbKnuckle_2_3,thumbKnuckle_3_0,thumbKnuckle_3_1,thumbKnuckle_3_2,thumbKnuckle_3_3,thumbIntermediateBase_0_0,thumbIntermediateBase_0_1,thumbIntermediateBase_0_2,thumbIntermediateBase_0_3,thumbIntermediateBase_1_0,thumbIntermediateBase_1_1,thumbIntermediateBase_1_2,thumbIntermediateBase_1_3,thumbIntermediateBase_2_0,thumbIntermediateBase_2_1,thumbIntermediateBase_2_2,thumbIntermediateBase_2_3,thumbIntermediateBase_3_0,thumbIntermediateBase_3_1,thumbIntermediateBase_3_2,thumbIntermediateBase_3_3,thumbIntermediateTip_0_0,thumbIntermediateTip_0_1,thumbIntermediateTip_0_2,thumbIntermediateTip_0_3,thumbIntermediateTip_1_0,thumbIntermediateTip_1_1,thumbIntermediateTip_1_2,thumbIntermediateTip_1_3,thumbIntermediateTip_2_0,thumbIntermediateTip_2_1,thumbIntermediateTip_2_2,thumbIntermediateTip_2_3,thumbIntermediateTip_3_0,thumbIntermediateTip_3_1,thumbIntermediateTip_3_2,thumbIntermediateTip_3_3,thumbTip_0_0,thumbTip_0_1,thumbTip_0_2,thumbTip_0_3,thumbTip_1_0,thumbTip_1_1,thumbTip_1_2,thumbTip_1_3,thumbTip_2_0,thumbTip_2_1,thumbTip_2_2,thumbTip_2_3,thumbTip_3_0,thumbTip_3_1,thumbTip_3_2,thumbTip_3_3,indexFingerMetacarpal_0_0,indexFingerMetacarpal_0_1,indexFingerMetacarpal_0_2,indexFingerMetacarpal_0_3,indexFingerMetacarpal_1_0,indexFingerMetacarpal_1_1,indexFingerMetacarpal_1_2,indexFingerMetacarpal_1_3,indexFingerMetacarpal_2_0,indexFingerMetacarpal_2_1,indexFingerMetacarpal_2_2,indexFingerMetacarpal_2_3,indexFingerMetacarpal_3_0,indexFingerMetacarpal_3_1,indexFingerMetacarpal_3_2,indexFingerMetacarpal_3_3,indexFingerKnuckle_0_0,indexFingerKnuckle_0_1,indexFingerKnuckle_0_2,indexFingerKnuckle_0_3,indexFingerKnuckle_1_0,indexFingerKnuckle_1_1,indexFingerKnuckle_1_2,indexFingerKnuckle_1_3,indexFingerKnuckle_2_0,indexFingerKnuckle_2_1,indexFingerKnuckle_2_2,indexFingerKnuckle_2_3,indexFingerKnuckle_3_0,indexFingerKnuckle_3_1,indexFingerKnuckle_3_2,indexFingerKnuckle_3_3,indexFingerIntermediateBase_0_0,indexFingerIntermediateBase_0_1,indexFingerIntermediateBase_0_2,indexFingerIntermediateBase_0_3,indexFingerIntermediateBase_1_0,indexFingerIntermediateBase_1_1,indexFingerIntermediateBase_1_2,indexFingerIntermediateBase_1_3,indexFingerIntermediateBase_2_0,indexFingerIntermediateBase_2_1,indexFingerIntermediateBase_2_2,indexFingerIntermediateBase_2_3,indexFingerIntermediateBase_3_0,indexFingerIntermediateBase_3_1,indexFingerIntermediateBase_3_2,indexFingerIntermediateBase_3_3,indexFingerIntermediateTip_0_0,indexFingerIntermediateTip_0_1,indexFingerIntermediateTip_0_2,indexFingerIntermediateTip_0_3,indexFingerIntermediateTip_1_0,indexFingerIntermediateTip_1_1,indexFingerIntermediateTip_1_2,indexFingerIntermediateTip_1_3,indexFingerIntermediateTip_2_0,indexFingerIntermediateTip_2_1,indexFingerIntermediateTip_2_2,indexFingerIntermediateTip_2_3,indexFingerIntermediateTip_3_0,indexFingerIntermediateTip_3_1,indexFingerIntermediateTip_3_2,indexFingerIntermediateTip_3_3,indexFingerTip_0_0,indexFingerTip_0_1,indexFingerTip_0_2,indexFingerTip_0_3,indexFingerTip_1_0,indexFingerTip_1_1,indexFingerTip_1_2,indexFingerTip_1_3,indexFingerTip_2_0,indexFingerTip_2_1,indexFingerTip_2_2,indexFingerTip_2_3,indexFingerTip_3_0,indexFingerTip_3_1,indexFingerTip_3_2,indexFingerTip_3_3,middleFingerMetacarpal_0_0,middleFingerMetacarpal_0_1,middleFingerMetacarpal_0_2,middleFingerMetacarpal_0_3,middleFingerMetacarpal_1_0,middleFingerMetacarpal_1_1,middleFingerMetacarpal_1_2,middleFingerMetacarpal_1_3,middleFingerMetacarpal_2_0,middleFingerMetacarpal_2_1,middleFingerMetacarpal_2_2,middleFingerMetacarpal_2_3,middleFingerMetacarpal_3_0,middleFingerMetacarpal_3_1,middleFingerMetacarpal_3_2,middleFingerMetacarpal_3_3,middleFingerKnuckle_0_0,middleFingerKnuckle_0_1,middleFingerKnuckle_0_2,middleFingerKnuckle_0_3,middleFingerKnuckle_1_0,middleFingerKnuckle_1_1,middleFingerKnuckle_1_2,middleFingerKnuckle_1_3,middleFingerKnuckle_2_0,middleFingerKnuckle_2_1,middleFingerKnuckle_2_2,middleFingerKnuckle_2_3,middleFingerKnuckle_3_0,middleFingerKnuckle_3_1,middleFingerKnuckle_3_2,middleFingerKnuckle_3_3,middleFingerIntermediateBase_0_0,middleFingerIntermediateBase_0_1,middleFingerIntermediateBase_0_2,middleFingerIntermediateBase_0_3,middleFingerIntermediateBase_1_0,middleFingerIntermediateBase_1_1,middleFingerIntermediateBase_1_2,middleFingerIntermediateBase_1_3,middleFingerIntermediateBase_2_0,middleFingerIntermediateBase_2_1,middleFingerIntermediateBase_2_2,middleFingerIntermediateBase_2_3,middleFingerIntermediateBase_3_0,middleFingerIntermediateBase_3_1,middleFingerIntermediateBase_3_2,middleFingerIntermediateBase_3_3,middleFingerIntermediateTip_0_0,middleFingerIntermediateTip_0_1,middleFingerIntermediateTip_0_2,middleFingerIntermediateTip_0_3,middleFingerIntermediateTip_1_0,middleFingerIntermediateTip_1_1,middleFingerIntermediateTip_1_2,middleFingerIntermediateTip_1_3,middleFingerIntermediateTip_2_0,middleFingerIntermediateTip_2_1,middleFingerIntermediateTip_2_2,middleFingerIntermediateTip_2_3,middleFingerIntermediateTip_3_0,middleFingerIntermediateTip_3_1,middleFingerIntermediateTip_3_2,middleFingerIntermediateTip_3_3,middleFingerTip_0_0,middleFingerTip_0_1,middleFingerTip_0_2,middleFingerTip_0_3,middleFingerTip_1_0,middleFingerTip_1_1,middleFingerTip_1_2,middleFingerTip_1_3,middleFingerTip_2_0,middleFingerTip_2_1,middleFingerTip_2_2,middleFingerTip_2_3,middleFingerTip_3_0,middleFingerTip_3_1,middleFingerTip_3_2,middleFingerTip_3_3,ringFingerMetacarpal_0_0,ringFingerMetacarpal_0_1,ringFingerMetacarpal_0_2,ringFingerMetacarpal_0_3,ringFingerMetacarpal_1_0,ringFingerMetacarpal_1_1,ringFingerMetacarpal_1_2,ringFingerMetacarpal_1_3,ringFingerMetacarpal_2_0,ringFingerMetacarpal_2_1,ringFingerMetacarpal_2_2,ringFingerMetacarpal_2_3,ringFingerMetacarpal_3_0,ringFingerMetacarpal_3_1,ringFingerMetacarpal_3_2,ringFingerMetacarpal_3_3,ringFingerKnuckle_0_0,ringFingerKnuckle_0_1,ringFingerKnuckle_0_2,ringFingerKnuckle_0_3,ringFingerKnuckle_1_0,ringFingerKnuckle_1_1,ringFingerKnuckle_1_2,ringFingerKnuckle_1_3,ringFingerKnuckle_2_0,ringFingerKnuckle_2_1,ringFingerKnuckle_2_2,ringFingerKnuckle_2_3,ringFingerKnuckle_3_0,ringFingerKnuckle_3_1,ringFingerKnuckle_3_2,ringFingerKnuckle_3_3,ringFingerIntermediateBase_0_0,ringFingerIntermediateBase_0_1,ringFingerIntermediateBase_0_2,ringFingerIntermediateBase_0_3,ringFingerIntermediateBase_1_0,ringFingerIntermediateBase_1_1,ringFingerIntermediateBase_1_2,ringFingerIntermediateBase_1_3,ringFingerIntermediateBase_2_0,ringFingerIntermediateBase_2_1,ringFingerIntermediateBase_2_2,ringFingerIntermediateBase_2_3,ringFingerIntermediateBase_3_0,ringFingerIntermediateBase_3_1,ringFingerIntermediateBase_3_2,ringFingerIntermediateBase_3_3,ringFingerIntermediateTip_0_0,ringFingerIntermediateTip_0_1,ringFingerIntermediateTip_0_2,ringFingerIntermediateTip_0_3,ringFingerIntermediateTip_1_0,ringFingerIntermediateTip_1_1,ringFingerIntermediateTip_1_2,ringFingerIntermediateTip_1_3,ringFingerIntermediateTip_2_0,ringFingerIntermediateTip_2_1,ringFingerIntermediateTip_2_2,ringFingerIntermediateTip_2_3,ringFingerIntermediateTip_3_0,ringFingerIntermediateTip_3_1,ringFingerIntermediateTip_3_2,ringFingerIntermediateTip_3_3,ringFingerTip_0_0,ringFingerTip_0_1,ringFingerTip_0_2,ringFingerTip_0_3,ringFingerTip_1_0,ringFingerTip_1_1,ringFingerTip_1_2,ringFingerTip_1_3,ringFingerTip_2_0,ringFingerTip_2_1,ringFingerTip_2_2,ringFingerTip_2_3,ringFingerTip_3_0,ringFingerTip_3_1,ringFingerTip_3_2,ringFingerTip_3_3,littleFingerMetacarpal_0_0,littleFingerMetacarpal_0_1,littleFingerMetacarpal_0_2,littleFingerMetacarpal_0_3,littleFingerMetacarpal_1_0,littleFingerMetacarpal_1_1,littleFingerMetacarpal_1_2,littleFingerMetacarpal_1_3,littleFingerMetacarpal_2_0,littleFingerMetacarpal_2_1,littleFingerMetacarpal_2_2,littleFingerMetacarpal_2_3,littleFingerMetacarpal_3_0,littleFingerMetacarpal_3_1,littleFingerMetacarpal_3_2,littleFingerMetacarpal_3_3,littleFingerKnuckle_0_0,littleFingerKnuckle_0_1,littleFingerKnuckle_0_2,littleFingerKnuckle_0_3,littleFingerKnuckle_1_0,littleFingerKnuckle_1_1,littleFingerKnuckle_1_2,littleFingerKnuckle_1_3,littleFingerKnuckle_2_0,littleFingerKnuckle_2_1,littleFingerKnuckle_2_2,littleFingerKnuckle_2_3,littleFingerKnuckle_3_0,littleFingerKnuckle_3_1,littleFingerKnuckle_3_2,littleFingerKnuckle_3_3,littleFingerIntermediateBase_0_0,littleFingerIntermediateBase_0_1,littleFingerIntermediateBase_0_2,littleFingerIntermediateBase_0_3,littleFingerIntermediateBase_1_0,littleFingerIntermediateBase_1_1,littleFingerIntermediateBase_1_2,littleFingerIntermediateBase_1_3,littleFingerIntermediateBase_2_0,littleFingerIntermediateBase_2_1,littleFingerIntermediateBase_2_2,littleFingerIntermediateBase_2_3,littleFingerIntermediateBase_3_0,littleFingerIntermediateBase_3_1,littleFingerIntermediateBase_3_2,littleFingerIntermediateBase_3_3,littleFingerIntermediateTip_0_0,littleFingerIntermediateTip_0_1,littleFingerIntermediateTip_0_2,littleFingerIntermediateTip_0_3,littleFingerIntermediateTip_1_0,littleFingerIntermediateTip_1_1,littleFingerIntermediateTip_1_2,littleFingerIntermediateTip_1_3,littleFingerIntermediateTip_2_0,littleFingerIntermediateTip_2_1,littleFingerIntermediateTip_2_2,littleFingerIntermediateTip_2_3,littleFingerIntermediateTip_3_0,littleFingerIntermediateTip_3_1,littleFingerIntermediateTip_3_2,littleFingerIntermediateTip_3_3,littleFingerTip_0_0,littleFingerTip_0_1,littleFingerTip_0_2,littleFingerTip_0_3,littleFingerTip_1_0,littleFingerTip_1_1,littleFingerTip_1_2,littleFingerTip_1_3,littleFingerTip_2_0,littleFingerTip_2_1,littleFingerTip_2_2,littleFingerTip_2_3,littleFingerTip_3_0,littleFingerTip_3_1,littleFingerTip_3_2,littleFingerTip_3_3,forearmWrist_0_0,forearmWrist_0_1,forearmWrist_0_2,forearmWrist_0_3,forearmWrist_1_0,forearmWrist_1_1,forearmWrist_1_2,forearmWrist_1_3,forearmWrist_2_0,forearmWrist_2_1,forearmWrist_2_2,forearmWrist_2_3,forearmWrist_3_0,forearmWrist_3_1,forearmWrist_3_2,forearmWrist_3_3,forearmArm_0_0,forearmArm_0_1,forearmArm_0_2,forearmArm_0_3,forearmArm_1_0,forearmArm_1_1,forearmArm_1_2,forearmArm_1_3,forearmArm_2_0,forearmArm_2_1,forearmArm_2_2,forearmArm_2_3,forearmArm_3_0,forearmArm_3_1,forearmArm_3_2,forearmArm_3_3
# ```

# %%
# wrist と thumbTip, indexFingerTip, middleFingerTip, ringFingerTip, littleFingerTip の距離を計算
df['distance_wrist_thumbTip'] = ((df['wrist_3_0'] - df['thumbTip_3_0'])**2 + (df['wrist_3_1'] - df['thumbTip_3_1'])**2 + (df['wrist_3_2'] - df['thumbTip_3_2'])**2)**0.5
df['distance_wrist_indexFingerTip'] = ((df['wrist_3_0'] - df['indexFingerTip_3_0'])**2 + (df['wrist_3_1'] - df['indexFingerTip_3_1'])**2 + (df['wrist_3_2'] - df['indexFingerTip_3_2'])**2)**0.5
df['distance_wrist_middleFingerTip'] = ((df['wrist_3_0'] - df['middleFingerTip_3_0'])**2 + (df['wrist_3_1'] - df['middleFingerTip_3_1'])**2 + (df['wrist_3_2'] - df['middleFingerTip_3_2'])**2)**0.5
df['distance_wrist_ringFingerTip'] = ((df['wrist_3_0'] - df['ringFingerTip_3_0'])**2 + (df['wrist_3_1'] - df['ringFingerTip_3_1'])**2 + (df['wrist_3_2'] - df['ringFingerTip_3_2'])**2)**0.5
df['distance_wrist_littleFingerTip'] = ((df['wrist_3_0'] - df['littleFingerTip_3_0'])**2 + (df['wrist_3_1'] - df['littleFingerTip_3_1'])**2 + (df['wrist_3_2'] - df['littleFingerTip_3_2'])**2)**0.5

df.to_csv(f"data/{latest_file}.csv", index=False)

# %%
# グラフ描画
# subplot で 5つ横に並べる
fig, axs = plt.subplots(1, 5, figsize=(20, 4))
ylim = [0.05,0.20]
axs[0].plot(df['distance_wrist_thumbTip'], color='black')
axs[0].set_ylim(ylim)
axs[0].set_title("distance_wrist_thumbTip")
axs[1].plot(df['distance_wrist_indexFingerTip'], color='orange')
axs[1].set_ylim(ylim)
axs[1].set_title("distance_wrist_indexFingerTip")
axs[2].plot(df['distance_wrist_middleFingerTip'], color='green')
axs[2].set_ylim(ylim)
axs[2].set_title("distance_wrist_middleFingerTip")
axs[3].plot(df['distance_wrist_ringFingerTip'], color='blue')
axs[3].set_ylim(ylim)
axs[3].set_title("distance_wrist_ringFingerTip")
axs[4].plot(df['distance_wrist_littleFingerTip'], color='red')
axs[4].set_ylim(ylim)
axs[4].set_title("distance_wrist_littleFingerTip")
plt.tight_layout()
plt.show()
